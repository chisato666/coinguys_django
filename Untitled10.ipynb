# %%
import requests
from datetime import datetime, timedelta

symbol='BTC_USDT'
url = f'https://contract.mexc.com/api/v1/contract/kline/{symbol}?interval=Min60&limit=10'
response = requests.get(url)
data = response.json()
highest_price = None

for kline in data['data']['high']:    
    print(kline)

# def get_highest_price(symbol):
#     #url="https://contract.mexc.com/api/v1/contract/kline/"+ symbol + "?interval="+ interval +"&start="+ str(start)+ "&end="+ str(end)

    
#     for kline in data['data']['time']:    
#         print(kline)
#         if highest_price is None or kline > highest_price:
#             highest_price = kline
#     return highest_price

# # Example usage
# symbols = ['BTC_USDT', 'ETH_USDT']
# for symbol in symbols:
#     highest_price = get_highest_price(symbol)
#     print(f"The highest price for symbol {symbol} in the past 10 hours is: {highest_price:.8f}")
# Out:
# 26273.2
# 26260.2
# 26373.0
# 26376.2
# 26245.1
# 26279.0
# 26257.8
# 26185.6
# 26033.0
# 25883.1

# %%
data
# Out:
# {'success': True,
#  'code': 0,
#  'data': {'time': [1694138400,
#    1694142000,
#    1694145600,
#    1694149200,
#    1694152800,
#    1694156400,
#    1694160000,
#    1694163600,
#    1694167200,
#    1694170800],
#   'open': [26232.1,
#    26235.0,
#    26235.7,
#    26334.1,
#    26225.6,
#    26211.3,
#    26244.1,
#    26184.5,
#    26032.2,
#    25819.7],
#   'close': [26235.0,
#    26235.7,
#    26334.1,
#    26225.6,
#    26211.3,
#    26244.1,
#    26184.5,
#    26032.2,
#    25819.7,
#    25844.0],
#   'high': [26273.2,
#    26260.2,
#    26373.0,
#    26376.2,
#    26245.1,
#    26279.0,
#    26257.8,
#    26185.6,
#    26033.0,
#    25869.9],
#   'low': [26184.0,
#    26200.1,
#    26235.6,
#    26225.6,
#    26172.2,
#    26211.2,
#    26173.1,
#    26023.0,
#    25631.0,
#    25801.1],
#   'vol': [40893554.0,
#    32557892.0,
#    50536792.0,
#    38952113.0,
#    32489044.0,
#    22232083.0,
#    23787423.0,
#    63323608.0,
#    132256356.0,
#    14955297.0],
# ...
